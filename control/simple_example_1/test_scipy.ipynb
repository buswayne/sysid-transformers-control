# %%
from scipy import signal
import matplotlib.pyplot as plt

# %%
num = [1]
num_proper = [0.01, 1]
den = [1/4, 1]
G_tf = signal.lti(num, den)
G_tf_proper = signal.lti(num_proper, den)
G_ss = signal.tf2ss(num_proper, den)
# A, B, C, D, _ = signal.cont2discrete(G_ss, 0.01, 'tustin')

# %%
G_ss
# Out:
# (array([[-4.]]), array([[1.]]), array([[3.84]]), array([[0.04]]))

# %%
plt.plot(signal.step(G_tf)[0], signal.step(G_tf)[1])
plt.plot(signal.step(G_tf_proper)[0], signal.step(G_tf_proper)[1], '--')
